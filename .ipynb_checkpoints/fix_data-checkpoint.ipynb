# %%
from fastai.vision import *
import fastai
import pandas as pd
import glob
# %config Completer.use_jedi = False
# Out:
# /opt/conda/envs/fastai_v1/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Config option `use_jedi` not recognized by `IPCompleter`.
#   """

# %%
fastai.__version__
# Out:
# '1.0.61'

# %%
#local path
#annot_path = Path('/home/fredrikmathisen/Documents/data/2-class_data/anno_dest/')

#Path GCloud
annot_path = Path('/home/jupyter/data/2_class_test/anno_dest/')
img_path = Path('/home/jupyter/data/2_class_test/img_dest/')

# %%
import xml.etree.ElementTree as ET


def read_content(xml_file: str):
    filename=xml_file.split('/')[6][:-4]
    filename=filename+'.png'
    tree = ET.parse(xml_file)
    root = tree.getroot()

    list_with_all_boxes = []
    list_with_cls = []
    final_list=[]
    for boxes in root.iter('object'):
        filename = str(root.find('filename').text)
        filename = filename+'.png'
        classes = str(boxes.find('name').text)

        ymin, xmin, ymax, xmax = None, None, None, None

        ymin = int(boxes.find("bndbox/ymin").text)
        xmin = int(boxes.find("bndbox/xmin").text)
        ymax = int(boxes.find("bndbox/ymax").text)
        xmax = int(boxes.find("bndbox/xmax").text)

        list_with_single_boxes = [ymin, xmin, ymax, xmax]
        list_with_all_boxes.append(list_with_single_boxes)
        list_with_cls.append(classes)
        #final_list.append(tuple((list_with_single_boxes, classes)))

    return filename, list_with_all_boxes, list_with_cls

name, boxes, cls = read_content(str(annot_path)+ "/000002.xml")
lbl2bbox = tuple((boxes,cls))

# %%
name
# Out:
# '000002.png'

# %%
boxes
# Out:
# []

# %%
cls
# Out:
# []

# %%
lbl2bbox
# Out:
# ([], [])

# %%
img2bbox = dict(zip([name],[lbl2bbox]))

# %%
img2bbox['000002.png']
# Out:
# ([], [])

# %%
#img = open_image('/home/fredrikmathisen/Documents/data/2-class_data/img_dest/000001.png')
img = open_image('/home/jupyter/data/2_class_test/img_dest/000002.png')

# %%
bbox = ImageBBox.create(*img.size, img2bbox['000002.png'][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-145-36d021926557> in <module>()
# ----> 1 bbox = ImageBBox.create(*img.size, img2bbox['000002.png'][0])
#
# /opt/conda/envs/fastai_v1/lib/python3.7/site-packages/fastai/vision/image.py in create(cls, h, w, bboxes, labels, classes, pad_idx, scale)
#     357         if isinstance(bboxes, np.ndarray) and bboxes.dtype == np.object: bboxes = np.array([bb for bb in bboxes])
#     358         bboxes = tensor(bboxes).float()
# --> 359         tr_corners = torch.cat([bboxes[:,0][:,None], bboxes[:,3][:,None]], 1)
#     360         bl_corners = bboxes[:,1:3].flip(1)
#     361         bboxes = torch.cat([bboxes[:,:2], tr_corners, bl_corners, bboxes[:,2:]], 1)
#
# IndexError: too many indices for tensor of dimension 0

# %%
img.show(figsize=(10,10),y=bbox)

# %%
input_xml_list = sorted(glob.glob(str(annot_path) + '/*.xml'))

# %%
(input_xml_list)
# Out:
# ['/home/jupyter/data/2_class_test/anno_dest/000001.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000002.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000003.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000004.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000005.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000006.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000007.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000008.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000009.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000010.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000011.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000012.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000013.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000014.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000015.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000016.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000017.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000018.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000019.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000020.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000021.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000022.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000023.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000024.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000025.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000026.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000027.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000028.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000029.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000030.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000031.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000032.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000033.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000034.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000035.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000036.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000037.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000038.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000039.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000040.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000041.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000042.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000043.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000044.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000045.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000046.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000047.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000048.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000049.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000050.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000051.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000052.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000053.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000054.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000055.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000056.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000057.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000058.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000059.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000060.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000061.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000062.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000063.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000064.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000065.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000066.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000067.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000068.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000069.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000070.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000071.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000072.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000073.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000074.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000075.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000076.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000077.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000078.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000079.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000080.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000081.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000082.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000083.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000084.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000085.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000086.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000087.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000088.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000089.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000090.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000091.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000092.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000093.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000094.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000095.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000096.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000097.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000098.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000099.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000100.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000101.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000102.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000103.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000104.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000105.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000106.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000107.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000108.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000109.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000110.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000111.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000112.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000113.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000114.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000115.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000116.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000117.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000118.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000119.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000120.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000121.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000122.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000123.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000124.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000125.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000126.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000127.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000128.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000129.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000130.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000131.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000132.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000133.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000134.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000135.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000136.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000137.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000138.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000139.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000140.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000141.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000142.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000143.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000144.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000145.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000146.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000147.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000148.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000149.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000150.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000151.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000152.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000153.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000154.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000155.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000156.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000157.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000158.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000159.xml',
#  '/home/jupyter/data/2_class_test/anno_dest/000160.xml']

# %%
filenames=[]
bboxes=[]
classes=[]
lbl2bbox=[]
for files in range(len(input_xml_list)):
    names, bbox, cls = read_content(input_xml_list[files])
    filenames.append(names)
    lbl2bbox.append(tuple((bbox,cls)))

# %%
lbl2bbox
# Out:
# [([[28, 28, 41, 71],
#    [45, 19, 59, 151],
#    [63, 19, 73, 34],
#    [78, 19, 91, 116],
#    [98, 19, 112, 169]],
#   ['background', 'background', 'text', 'background', 'background']),
#  ([], []),
#  ([[27, 209, 40, 256], [46, 207, 59, 256]], ['text', 'background']),
#  ([[27, 0, 40, 19], [46, 0, 59, 121]], ['text', 'background']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[104, 211, 116, 214]], ['text']),
#  ([], []),
#  ([[216, 31, 229, 173]], ['background']),
#  ([], []),
#  ([[224, 217, 235, 256], [204, 217, 217, 243]], ['background', 'background']),
#  ([[224, 0, 235, 41]], ['background']),
#  ([], []),
#  ([], []),
#  ([[23, 219, 36, 256], [40, 218, 53, 256]], ['text', 'background']),
#  ([[23, 0, 36, 96], [40, 0, 53, 15]], ['text', 'background']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[152, 250, 162, 256]], ['text']),
#  ([[152, 0, 162, 0]], ['text']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[207, 223, 219, 256],
#    [185, 223, 198, 256],
#    [164, 222, 175, 256],
#    [143, 222, 156, 256],
#    [122, 222, 132, 256]],
#   ['background', 'background', 'text', 'text', 'text']),
#  ([[207, 0, 219, 136],
#    [185, 0, 198, 55],
#    [164, 0, 175, 25],
#    [143, 0, 156, 118],
#    [122, 0, 132, 73]],
#   ['background', 'background', 'text', 'text', 'text']),
#  ([[27, 20, 39, 28], [46, 20, 60, 190], [65, 20, 78, 126], [85, 20, 98, 117]],
#   ['text', 'background', 'background', 'text']),
#  ([], []),
#  ([[23, 218, 36, 256]], ['text']),
#  ([[23, 0, 36, 50]], ['text']),
#  ([], []),
#  ([[94, 252, 107, 256]], ['text']),
#  ([[94, 0, 107, 13]], ['text']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[212, 31, 222, 74],
#    [193, 33, 206, 181],
#    [174, 30, 187, 137],
#    [155, 33, 168, 173],
#    [136, 30, 147, 108]],
#   ['background', 'background', 'background', 'background', 'background']),
#  ([], []),
#  ([], []),
#  ([[205, 17, 218, 51], [186, 18, 196, 42]], ['text', 'text']),
#  ([[22, 18, 39, 212], [49, 31, 66, 73], [77, 30, 94, 204]],
#   ['text', 'background', 'text']),
#  ([], []),
#  ([[22, 227, 39, 256],
#    [49, 227, 66, 247],
#    [76, 227, 91, 256],
#    [103, 226, 119, 256]],
#   ['background', 'text', 'background', 'text']),
#  ([[22, 0, 39, 123], [76, 0, 91, 90], [103, 0, 119, 79]],
#   ['background', 'background', 'text']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[217, 220, 230, 228]], ['text']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[209, 27, 222, 71],
#    [179, 28, 195, 91],
#    [155, 27, 168, 125],
#    [128, 30, 141, 113],
#    [101, 31, 118, 190]],
#   ['background', 'text', 'background', 'background', 'background']),
#  ([], []),
#  ([], []),
#  ([[203, 20, 223, 214],
#    [183, 19, 196, 118],
#    [161, 19, 178, 149],
#    [139, 22, 155, 193],
#    [116, 30, 129, 40]],
#   ['background', 'text', 'background', 'text', 'background']),
#  ([[18, 21, 32, 164], [39, 22, 49, 64]], ['text', 'text']),
#  ([[222, 247, 232, 254]], ['background']),
#  ([[23, 224, 35, 256], [47, 225, 54, 239], [66, 222, 78, 256]],
#   ['background', 'text', 'text']),
#  ([[23, 0, 35, 45], [66, 0, 78, 19]], ['background', 'text']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[223, 23, 237, 166],
#    [201, 23, 214, 94],
#    [179, 24, 193, 166],
#    [157, 23, 169, 112],
#    [135, 23, 148, 175]],
#   ['background', 'background', 'text', 'text', 'background']),
#  ([], []),
#  ([], []),
#  ([[218, 44, 228, 133],
#    [196, 45, 209, 205],
#    [175, 45, 188, 97],
#    [153, 45, 166, 70]],
#   ['text', 'background', 'text', 'background']),
#  ([[21, 15, 35, 121], [39, 14, 51, 130], [60, 14, 67, 31]],
#   ['text', 'text', 'text']),
#  ([], []),
#  ([[20, 211, 32, 234], [37, 210, 50, 256]], ['background', 'text']),
#  ([[37, 0, 50, 113]], ['text']),
#  ([], []),
#  ([], []),
#  ([[256, 171, 256, 177]], ['text']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[0, 171, 10, 177]], ['text']),
#  ([], []),
#  ([[222, 28, 233, 151], [200, 28, 215, 185], [182, 28, 195, 143]],
#   ['background', 'background', 'background']),
#  ([], []),
#  ([], []),
#  ([[218, 19, 228, 60],
#    [197, 19, 210, 171],
#    [176, 20, 188, 87],
#    [155, 20, 168, 108]],
#   ['background', 'background', 'background', 'text']),
#  ([[26, 12, 37, 34]], ['background']),
#  ([], []),
#  ([[20, 213, 33, 256], [45, 213, 58, 256]], ['text', 'background']),
#  ([[20, 0, 33, 109], [45, 0, 58, 32]], ['text', 'background']),
#  ([], []),
#  ([[142, 252, 155, 256]], ['background']),
#  ([[142, 0, 155, 26]], ['background']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[210, 218, 226, 256], [188, 220, 205, 256]], ['text', 'background']),
#  ([[210, 0, 226, 124], [188, 0, 205, 115]], ['text', 'background']),
#  ([[21, 20, 32, 77], [40, 19, 54, 147], [60, 19, 71, 77], [80, 20, 91, 67]],
#   ['text', 'text', 'background', 'text']),
#  ([], []),
#  ([[25, 208, 37, 256]], ['background']),
#  ([[25, 0, 37, 10]], ['background']),
#  ([], []),
#  ([[56, 112, 69, 129]], ['background']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[211, 30, 225, 207], [187, 30, 198, 47]], ['background', 'background']),
#  ([], []),
#  ([[222, 219, 236, 256],
#    [199, 219, 216, 256],
#    [180, 219, 195, 256],
#    [159, 218, 171, 256],
#    [138, 219, 151, 256]],
#   ['text', 'text', 'background', 'background', 'text']),
#  ([[222, 0, 236, 17],
#    [199, 0, 216, 148],
#    [180, 0, 195, 110],
#    [159, 0, 171, 140],
#    [138, 0, 151, 140]],
#   ['text', 'text', 'background', 'background', 'text']),
#  ([[27, 18, 40, 97], [46, 19, 59, 97], [65, 18, 78, 169]],
#   ['text', 'text', 'background']),
#  ([], []),
#  ([[25, 223, 37, 256],
#    [46, 225, 58, 256],
#    [66, 223, 76, 256],
#    [86, 224, 99, 256],
#    [106, 233, 117, 256]],
#   ['text', 'background', 'text', 'text', 'background']),
#  ([[25, 0, 37, 74],
#    [46, 0, 58, 56],
#    [66, 0, 76, 47],
#    [86, 0, 99, 65],
#    [106, 0, 117, 64]],
#   ['text', 'background', 'text', 'text', 'background']),
#  ([], []),
#  ([], []),
#  ([[218, 39, 228, 45]], ['text']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[214, 30, 227, 134]], ['text']),
#  ([], []),
#  ([], []),
#  ([[204, 32, 217, 111],
#    [182, 32, 194, 174],
#    [161, 32, 173, 198],
#    [140, 31, 152, 156]],
#   ['text', 'text', 'background', 'text']),
#  ([], []),
#  ([], []),
#  ([[14, 223, 33, 256]], ['background']),
#  ([[14, 0, 33, 173]], ['background']),
#  ([], []),
#  ([], []),
#  ([[53, 85, 67, 94]], ['text']),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([], []),
#  ([[211, 27, 230, 90], [178, 41, 198, 155], [151, 28, 161, 37]],
#   ['text', 'background', 'text']),
#  ([], []),
#  ([[183, 255, 205, 256]], ['background']),
#  ([[213, 11, 228, 61], [183, 0, 205, 126]], ['background', 'background'])]

# %%
img2bbox=dict(zip(filenames,lbl2bbox))

# %%
img2bbox
# Out:
# {'000001.png': ([[28, 28, 41, 71],
#    [45, 19, 59, 151],
#    [63, 19, 73, 34],
#    [78, 19, 91, 116],
#    [98, 19, 112, 169]],
#   ['background', 'background', 'text', 'background', 'background']),
#  '000002.png': ([], []),
#  '000003.png': ([[27, 209, 40, 256], [46, 207, 59, 256]],
#   ['text', 'background']),
#  '000004.png': ([[27, 0, 40, 19], [46, 0, 59, 121]], ['text', 'background']),
#  '000005.png': ([], []),
#  '000006.png': ([], []),
#  '000007.png': ([], []),
#  '000008.png': ([], []),
#  '000009.png': ([], []),
#  '000010.png': ([], []),
#  '000011.png': ([[104, 211, 116, 214]], ['text']),
#  '000012.png': ([], []),
#  '000013.png': ([[216, 31, 229, 173]], ['background']),
#  '000014.png': ([], []),
#  '000015.png': ([[224, 217, 235, 256], [204, 217, 217, 243]],
#   ['background', 'background']),
#  '000016.png': ([[224, 0, 235, 41]], ['background']),
#  '000017.png': ([], []),
#  '000018.png': ([], []),
#  '000019.png': ([[23, 219, 36, 256], [40, 218, 53, 256]],
#   ['text', 'background']),
#  '000020.png': ([[23, 0, 36, 96], [40, 0, 53, 15]], ['text', 'background']),
#  '000021.png': ([], []),
#  '000022.png': ([], []),
#  '000023.png': ([], []),
#  '000024.png': ([], []),
#  '000025.png': ([[152, 250, 162, 256]], ['text']),
#  '000026.png': ([[152, 0, 162, 0]], ['text']),
#  '000027.png': ([], []),
#  '000028.png': ([], []),
#  '000029.png': ([], []),
#  '000030.png': ([], []),
#  '000031.png': ([[207, 223, 219, 256],
#    [185, 223, 198, 256],
#    [164, 222, 175, 256],
#    [143, 222, 156, 256],
#    [122, 222, 132, 256]],
#   ['background', 'background', 'text', 'text', 'text']),
#  '000032.png': ([[207, 0, 219, 136],
#    [185, 0, 198, 55],
#    [164, 0, 175, 25],
#    [143, 0, 156, 118],
#    [122, 0, 132, 73]],
#   ['background', 'background', 'text', 'text', 'text']),
#  '000033.png': ([[27, 20, 39, 28],
#    [46, 20, 60, 190],
#    [65, 20, 78, 126],
#    [85, 20, 98, 117]],
#   ['text', 'background', 'background', 'text']),
#  '000034.png': ([], []),
#  '000035.png': ([[23, 218, 36, 256]], ['text']),
#  '000036.png': ([[23, 0, 36, 50]], ['text']),
#  '000037.png': ([], []),
#  '000038.png': ([[94, 252, 107, 256]], ['text']),
#  '000039.png': ([[94, 0, 107, 13]], ['text']),
#  '000040.png': ([], []),
#  '000041.png': ([], []),
#  '000042.png': ([], []),
#  '000043.png': ([], []),
#  '000044.png': ([], []),
#  '000045.png': ([[212, 31, 222, 74],
#    [193, 33, 206, 181],
#    [174, 30, 187, 137],
#    [155, 33, 168, 173],
#    [136, 30, 147, 108]],
#   ['background', 'background', 'background', 'background', 'background']),
#  '000046.png': ([], []),
#  '000047.png': ([], []),
#  '000048.png': ([[205, 17, 218, 51], [186, 18, 196, 42]], ['text', 'text']),
#  '000049.png': ([[22, 18, 39, 212], [49, 31, 66, 73], [77, 30, 94, 204]],
#   ['text', 'background', 'text']),
#  '000050.png': ([], []),
#  '000051.png': ([[22, 227, 39, 256],
#    [49, 227, 66, 247],
#    [76, 227, 91, 256],
#    [103, 226, 119, 256]],
#   ['background', 'text', 'background', 'text']),
#  '000052.png': ([[22, 0, 39, 123], [76, 0, 91, 90], [103, 0, 119, 79]],
#   ['background', 'background', 'text']),
#  '000053.png': ([], []),
#  '000054.png': ([], []),
#  '000055.png': ([], []),
#  '000056.png': ([], []),
#  '000057.png': ([[217, 220, 230, 228]], ['text']),
#  '000058.png': ([], []),
#  '000059.png': ([], []),
#  '000060.png': ([], []),
#  '000061.png': ([[209, 27, 222, 71],
#    [179, 28, 195, 91],
#    [155, 27, 168, 125],
#    [128, 30, 141, 113],
#    [101, 31, 118, 190]],
#   ['background', 'text', 'background', 'background', 'background']),
#  '000062.png': ([], []),
#  '000063.png': ([], []),
#  '000064.png': ([[203, 20, 223, 214],
#    [183, 19, 196, 118],
#    [161, 19, 178, 149],
#    [139, 22, 155, 193],
#    [116, 30, 129, 40]],
#   ['background', 'text', 'background', 'text', 'background']),
#  '000065.png': ([[18, 21, 32, 164], [39, 22, 49, 64]], ['text', 'text']),
#  '000066.png': ([[222, 247, 232, 254]], ['background']),
#  '000067.png': ([[23, 224, 35, 256], [47, 225, 54, 239], [66, 222, 78, 256]],
#   ['background', 'text', 'text']),
#  '000068.png': ([[23, 0, 35, 45], [66, 0, 78, 19]], ['background', 'text']),
#  '000069.png': ([], []),
#  '000070.png': ([], []),
#  '000071.png': ([], []),
#  '000072.png': ([], []),
#  '000073.png': ([], []),
#  '000074.png': ([], []),
#  '000075.png': ([], []),
#  '000076.png': ([], []),
#  '000077.png': ([[223, 23, 237, 166],
#    [201, 23, 214, 94],
#    [179, 24, 193, 166],
#    [157, 23, 169, 112],
#    [135, 23, 148, 175]],
#   ['background', 'background', 'text', 'text', 'background']),
#  '000078.png': ([], []),
#  '000079.png': ([], []),
#  '000080.png': ([[218, 44, 228, 133],
#    [196, 45, 209, 205],
#    [175, 45, 188, 97],
#    [153, 45, 166, 70]],
#   ['text', 'background', 'text', 'background']),
#  '000081.png': ([[21, 15, 35, 121], [39, 14, 51, 130], [60, 14, 67, 31]],
#   ['text', 'text', 'text']),
#  '000082.png': ([], []),
#  '000083.png': ([[20, 211, 32, 234], [37, 210, 50, 256]],
#   ['background', 'text']),
#  '000084.png': ([[37, 0, 50, 113]], ['text']),
#  '000085.png': ([], []),
#  '000086.png': ([], []),
#  '000087.png': ([[256, 171, 256, 177]], ['text']),
#  '000088.png': ([], []),
#  '000089.png': ([], []),
#  '000090.png': ([], []),
#  '000091.png': ([[0, 171, 10, 177]], ['text']),
#  '000092.png': ([], []),
#  '000093.png': ([[222, 28, 233, 151],
#    [200, 28, 215, 185],
#    [182, 28, 195, 143]],
#   ['background', 'background', 'background']),
#  '000094.png': ([], []),
#  '000095.png': ([], []),
#  '000096.png': ([[218, 19, 228, 60],
#    [197, 19, 210, 171],
#    [176, 20, 188, 87],
#    [155, 20, 168, 108]],
#   ['background', 'background', 'background', 'text']),
#  '000097.png': ([[26, 12, 37, 34]], ['background']),
#  '000098.png': ([], []),
#  '000099.png': ([[20, 213, 33, 256], [45, 213, 58, 256]],
#   ['text', 'background']),
#  '000100.png': ([[20, 0, 33, 109], [45, 0, 58, 32]], ['text', 'background']),
#  '000101.png': ([], []),
#  '000102.png': ([[142, 252, 155, 256]], ['background']),
#  '000103.png': ([[142, 0, 155, 26]], ['background']),
#  '000104.png': ([], []),
#  '000105.png': ([], []),
#  '000106.png': ([], []),
#  '000107.png': ([], []),
#  '000108.png': ([], []),
#  '000109.png': ([], []),
#  '000110.png': ([], []),
#  '000111.png': ([[210, 218, 226, 256], [188, 220, 205, 256]],
#   ['text', 'background']),
#  '000112.png': ([[210, 0, 226, 124], [188, 0, 205, 115]],
#   ['text', 'background']),
#  '000113.png': ([[21, 20, 32, 77],
#    [40, 19, 54, 147],
#    [60, 19, 71, 77],
#    [80, 20, 91, 67]],
#   ['text', 'text', 'background', 'text']),
#  '000114.png': ([], []),
#  '000115.png': ([[25, 208, 37, 256]], ['background']),
#  '000116.png': ([[25, 0, 37, 10]], ['background']),
#  '000117.png': ([], []),
#  '000118.png': ([[56, 112, 69, 129]], ['background']),
#  '000119.png': ([], []),
#  '000120.png': ([], []),
#  '000121.png': ([], []),
#  '000122.png': ([], []),
#  '000123.png': ([], []),
#  '000124.png': ([], []),
#  '000125.png': ([[211, 30, 225, 207], [187, 30, 198, 47]],
#   ['background', 'background']),
#  '000126.png': ([], []),
#  '000127.png': ([[222, 219, 236, 256],
#    [199, 219, 216, 256],
#    [180, 219, 195, 256],
#    [159, 218, 171, 256],
#    [138, 219, 151, 256]],
#   ['text', 'text', 'background', 'background', 'text']),
#  '000128.png': ([[222, 0, 236, 17],
#    [199, 0, 216, 148],
#    [180, 0, 195, 110],
#    [159, 0, 171, 140],
#    [138, 0, 151, 140]],
#   ['text', 'text', 'background', 'background', 'text']),
#  '000129.png': ([[27, 18, 40, 97], [46, 19, 59, 97], [65, 18, 78, 169]],
#   ['text', 'text', 'background']),
#  '000130.png': ([], []),
#  '000131.png': ([[25, 223, 37, 256],
#    [46, 225, 58, 256],
#    [66, 223, 76, 256],
#    [86, 224, 99, 256],
#    [106, 233, 117, 256]],
#   ['text', 'background', 'text', 'text', 'background']),
#  '000132.png': ([[25, 0, 37, 74],
#    [46, 0, 58, 56],
#    [66, 0, 76, 47],
#    [86, 0, 99, 65],
#    [106, 0, 117, 64]],
#   ['text', 'background', 'text', 'text', 'background']),
#  '000133.png': ([], []),
#  '000134.png': ([], []),
#  '000135.png': ([[218, 39, 228, 45]], ['text']),
#  '000136.png': ([], []),
#  '000137.png': ([], []),
#  '000138.png': ([], []),
#  '000139.png': ([], []),
#  '000140.png': ([], []),
#  '000141.png': ([[214, 30, 227, 134]], ['text']),
#  '000142.png': ([], []),
#  '000143.png': ([], []),
#  '000144.png': ([[204, 32, 217, 111],
#    [182, 32, 194, 174],
#    [161, 32, 173, 198],
#    [140, 31, 152, 156]],
#   ['text', 'text', 'background', 'text']),
#  '000145.png': ([], []),
#  '000146.png': ([], []),
#  '000147.png': ([[14, 223, 33, 256]], ['background']),
#  '000148.png': ([[14, 0, 33, 173]], ['background']),
#  '000149.png': ([], []),
#  '000150.png': ([], []),
#  '000151.png': ([[53, 85, 67, 94]], ['text']),
#  '000152.png': ([], []),
#  '000153.png': ([], []),
#  '000154.png': ([], []),
#  '000155.png': ([], []),
#  '000156.png': ([], []),
#  '000157.png': ([[211, 27, 230, 90], [178, 41, 198, 155], [151, 28, 161, 37]],
#   ['text', 'background', 'text']),
#  '000158.png': ([], []),
#  '000159.png': ([[183, 255, 205, 256]], ['background']),
#  '000160.png': ([[213, 11, 228, 61], [183, 0, 205, 126]],
#   ['background', 'background'])}

# %%
def get_y_func(o):
    name = o.split('/')[-1]
    ibb = img2bbox[name]
    bbox = ibb[0]
    labels = ibb[1]
    l=tuple([bbox, labels])
    return l

# %%
img_df=pd.DataFrame(img2bbox.keys())

# %%
img_df
# Out:
#               0
# 0    000001.png
# 1    000002.png
# 2    000003.png
# 3    000004.png
# 4    000005.png
# ..          ...
# 155  000156.png
# 156  000157.png
# 157  000158.png
# 158  000159.png
# 159  000160.png
#
# [160 rows x 1 columns]

# %%
def get_data(bs, size):
    src = ObjectItemList.from_df(img_df, img_path)
    src = src.split_by_rand_pct()
    src = src.label_from_func(get_y_func)
    src = src.transform(size=size, padding_mode='zeros', resize_method=ResizeMethod.SQUISH, tfm_y=True)
    return src.databunch(path=img_path, bs=bs, collate_fn=bb_pad_collate)

# %%
data=get_data(40,256)
# Out:
# /opt/conda/envs/fastai_v1/lib/python3.7/site-packages/fastai/core.py:302: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(a, dtype=dtype, **kwargs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-133-ff07f40e9681> in <module>()
# ----> 1 data=get_data(40,256)
#
# <ipython-input-132-59bfa417074b> in get_data(bs, size)
#       3     src = src.split_by_rand_pct()
#       4     src = src.label_from_func(get_y_func)
# ----> 5     src = src.transform(size=size, padding_mode='zeros', resize_method=ResizeMethod.SQUISH, tfm_y=True)
#       6     return src.databunch(path=img_path, bs=bs, collate_fn=bb_pad_collate)
#
# /opt/conda/envs/fastai_v1/lib/python3.7/site-packages/fastai/data_block.py in transform(self, tfms, **kwargs)
#     508         assert is_listy(tfms) and len(tfms) == 2, "Please pass a list of two lists of transforms (train and valid)."
#     509         self.train.transform(tfms[0], **kwargs)
# --> 510         self.valid.transform(tfms[1], **kwargs)
#     511         if self.test: self.test.transform(tfms[1], **kwargs)
#     512         return self
#
# /opt/conda/envs/fastai_v1/lib/python3.7/site-packages/fastai/data_block.py in transform(self, tfms, tfm_y, **kwargs)
#     729         if tfm_y is None: tfm_y = self.tfm_y
#     730         tfms_y = None if tfms is None else list(filter(lambda t: getattr(t, 'use_on_y', True), listify(tfms)))
# --> 731         if tfm_y: _check_kwargs(self.y, tfms_y, **kwargs)
#     732         self.tfms,self.tfmargs  = tfms,kwargs
#     733         self.tfm_y,self.tfms_y,self.tfmargs_y = tfm_y,tfms_y,kwargs
#
# /opt/conda/envs/fastai_v1/lib/python3.7/site-packages/fastai/data_block.py in _check_kwargs(ds, tfms, **kwargs)
#     595     if (tfms is None or len(tfms) == 0) and len(kwargs) == 0: return
#     596     if len(ds.items) >= 1:
# --> 597         x = ds[0]
#     598         try: x.apply_tfms(tfms, **kwargs)
#     599         except Exception as e:
#
# /opt/conda/envs/fastai_v1/lib/python3.7/site-packages/fastai/data_block.py in __getitem__(self, idxs)
#     118         "returns a single item based if `idxs` is an integer or a new `ItemList` object if `idxs` is a range."
#     119         idxs = try_int(idxs)
# --> 120         if isinstance(idxs, Integral): return self.get(idxs)
#     121         else: return self.new(self.items[idxs], inner_df=index_row(self.inner_df, idxs))
#     122
#
# /opt/conda/envs/fastai_v1/lib/python3.7/site-packages/fastai/vision/data.py in get(self, i)
#     353
#     354     def get(self, i):
# --> 355         return ImageBBox.create(*_get_size(self.x,i), *self.items[i], classes=self.classes, pad_idx=self.pad_idx)
#     356
#     357     def analyze_pred(self, pred): return pred
#
# /opt/conda/envs/fastai_v1/lib/python3.7/site-packages/fastai/vision/image.py in create(cls, h, w, bboxes, labels, classes, pad_idx, scale)
#     357         if isinstance(bboxes, np.ndarray) and bboxes.dtype == np.object: bboxes = np.array([bb for bb in bboxes])
#     358         bboxes = tensor(bboxes).float()
# --> 359         tr_corners = torch.cat([bboxes[:,0][:,None], bboxes[:,3][:,None]], 1)
#     360         bl_corners = bboxes[:,1:3].flip(1)
#     361         bboxes = torch.cat([bboxes[:,:2], tr_corners, bl_corners, bboxes[:,2:]], 1)
#
# IndexError: too many indices for tensor of dimension 0
